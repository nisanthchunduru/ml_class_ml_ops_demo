# %%
# !pip3 install requests
# Out:
# Running cells with '/opt/homebrew/bin/python3.12' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3.12 -m pip install ipykernel -U --user --force-reinstall'

# %%
import requests
import json

cust = [[678, "France", "Female", 45, 123232, 1, 1]]
request_body = json.dumps({"data": cust})
# url = "http://127.0.0.1:5000/predict"
url = "http://98.70.64.220:5000"

response = requests.post(url, request_body)
print(response.content)
# Out:
# Running cells with '/opt/homebrew/bin/python3.12' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3.12 -m pip install ipykernel -U --user --force-reinstall'
